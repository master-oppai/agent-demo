# %%
import pandas as pd

df = pd.read_csv("nids_source.csv")

df.head()
# Out:
#   Support Item Number                                  Support Item Name  \
# 0     01_002_0107_1_1  Assistance With Self-Care Activities - Standar...
# 1     01_003_0107_1_1                      Assistance From Live-In Carer
# 2     01_004_0107_1_1       Assistance with Personal Domestic Activities
# 3     01_010_0107_1_1  Assistance With Self-Care Activities - Night-T...
# 4     01_011_0107_1_1  Assistance With Self-Care Activities - Standar...
#
#    Registration Group Number    Registration Group Name  \
# 0                        107  Daily Personal Activities
# 1                        107  Daily Personal Activities
# 2                        107  Daily Personal Activities
# 3                        107  Daily Personal Activities
# 4                        107  Daily Personal Activities
#
#    Support Category Number  Support Category Number (PACE)  \
# 0                        1                             1.0
# 1                        1                             1.0
# ...
